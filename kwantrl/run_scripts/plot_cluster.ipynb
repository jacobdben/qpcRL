# %%
from kwantrl.plotting.plotting import plotter_class
from kwantrl.datahandling.datahandling import datahandler
import numpy as np

# %%
plotter=plotter_class(5,data_path="/Users/qdev_26/Documents/PhD/kwantrl/kwantrl_data/computerome_data")
plotter.loss()
plotter.result()
# Out:
# Dictionary contains 87 iterations with 20 measurements per iteration
# (<Figure size 1200x800 with 1 Axes>,
#  <AxesSubplot:title={'center':'CMA-id:5, result'}, xlabel='$V_{avg}$ [V]', ylabel='Conductance'>)

# %%
plotter.voltages()

# %%
plotter.wave_func([-2.5,-2,-1.5,-1,-0.5,0.2])
# Out:
# plotting wavefunction at x-axis value: -2.50
# plotting wavefunction at x-axis value: -1.99
# plotting wavefunction at x-axis value: -1.49
# plotting wavefunction at x-axis value: -0.99
# plotting wavefunction at x-axis value: -0.51
# plotting wavefunction at x-axis value: 0.19
# [<AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: -2.50, with conductance: 0.98'}>,
#  <AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: -1.99, with conductance: 1.99'}>,
#  <AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: -1.49, with conductance: 2.93'}>,
#  <AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: -0.99, with conductance: 3.96'}>,
#  <AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: -0.51, with conductance: 4.92'}>,
#  <AxesSubplot:title={'center':'CMA-id:5, WF at xaxis: 0.19, with conductance: 5.96'}>]
