# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from kwant_sim import *

# %%
L = 500
W = 300
a = 10

cl = 7*7
cw = 8*7


qpca = KwantChip(length=L, width=W, a=a, energy=0.04, continuum=True)

Vg = -2.5
Vp = -2.5
qpca.add_rect_gate([L//2-cl, L//2+cl, -W, W//2-cw], dist=100, V=Vg, gate_name='Vg1')
qpca.add_rect_gate([L//2-cl, L//2+cl, W//2+cw, 2*W], dist=100, V=Vg, gate_name='Vg2')


pixel1 = [L//2-cl, L//2-cl+4*7, W//2+cw-5*7, W//2+cw-7]
pixel2 = [L//2-cl+5*7, L//2-cl+9*7, W//2+cw-5*7, W//2+cw-7]
pixel3 = [L//2-cl+10*7, L//2-cl+14*7, W//2+cw-5*7, W//2+cw-7]
pixel4 = [L//2-cl, L//2-cl+4*7, W//2+cw-10*7, W//2+cw-6*7]
pixel5 = [L//2-cl+5*7, L//2-cl+9*7, W//2+cw-10*7, W//2+cw-6*7]
pixel6 = [L//2-cl+10*7, L//2-cl+14*7, W//2+cw-10*7, W//2+cw-6*7]
pixel7 = [L//2-cl, L//2-cl+4*7, W//2+cw-15*7, W//2+cw-11*7]
pixel8 = [L//2-cl+5*7, L//2-cl+9*7, W//2+cw-15*7, W//2+cw-11*7]
pixel9 = [L//2-cl+10*7, L//2-cl+14*7, W//2+cw-15*7, W//2+cw-11*7]

qpca.add_rect_gate(pixel1, dist=100, V=Vp, gate_name='Vp1')
qpca.add_rect_gate(pixel2, dist=100, V=Vp, gate_name='Vp2')
qpca.add_rect_gate(pixel3, dist=100, V=Vp, gate_name='Vp3')
qpca.add_rect_gate(pixel4, dist=100, V=Vp, gate_name='Vp4')
qpca.add_rect_gate(pixel5, dist=100, V=Vp, gate_name='Vp5')
qpca.add_rect_gate(pixel6, dist=100, V=Vp, gate_name='Vp6')
qpca.add_rect_gate(pixel7, dist=100, V=Vp, gate_name='Vp7')
qpca.add_rect_gate(pixel8, dist=100, V=Vp, gate_name='Vp8')
qpca.add_rect_gate(pixel9, dist=100, V=Vp, gate_name='Vp9')

qpca.build()
# Out:
# /home/jacob/Documents/Code/qpcRL/qpcRL/kwantrl/simulations/kwant_sim.py:271: UserWarning: Too large lattice spacing, Effective Mass Approximation may not be valid
#   warnings.warn("Too large lattice spacing, Effective Mass Approximation may not be valid", UserWarning)

# %%
qpca.plot_gates()
# Out:
# <img src="data:image/png;base64,..." width="640">
